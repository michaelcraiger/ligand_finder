# %%
import sqlite3
import json
import numpy as np
from ase import io, Atoms
from ase.build import molecule
from collections import Counter, defaultdict
from scipy.spatial import distance_matrix
from itertools import combinations
from openbabel.pybel import readfile
from sympy import Plane, Point3D

con = sqlite3.connect('ligands.db')
cur = con.cursor()

cur.execute('''CREATE TABLE IF NOT EXISTS ligand_data
              (ccdc_id text, denticity integer, coordinating_elements text, coordinating_indices text,
               original_metal integer, xyz text)'''
          )

# %%
import math
from math import pi ,sin, cos

def dotproduct(v1, v2):
    return sum((a*b) for a, b in zip(v1, v2))

def length(v):
    return math.sqrt(dotproduct(v, v))

def angle(v1, v2):
    return math.acos(dotproduct(v1, v2) / (length(v1) * length(v2)))

def R(theta, u):
    return [[cos(theta) + (u[0]**2) * (1-cos(theta)), 
             u[0] * u[1] * (1-cos(theta)) - u[2] * sin(theta), 
             u[0] * u[2] * (1 - cos(theta)) + u[1] * sin(theta)],
            [u[0] * u[1] * (1-cos(theta)) + u[2] * sin(theta),
             cos(theta) + (u[1]**2) * (1-cos(theta)),
             u[1] * u[2] * (1 - cos(theta)) - u[0] * sin(theta)],
            [u[0] * u[2] * (1-cos(theta)) - u[1] * sin(theta),
             u[1] * u[2] * (1-cos(theta)) + u[0] * sin(theta),
             cos(theta) + (u[2]**2) * (1-cos(theta))]]

def check_planarity(ligand_positions, ligand_connect_indices):
    plane = Plane(Point3D(list(ligand_positions[ligand_connect_indices[0]])), 
                  Point3D(list(ligand_positions[ligand_connect_indices[1]])), 
                  Point3D(list(ligand_positions[ligand_connect_indices[2]])))
    point2plane = []
    for idx, point in enumerate(ligand_positions):
        if idx in ligand_connect_indices:
            continue
        dist = plane.distance(Point3D(point))
        point2plane.append(float(dist))
    return point2plane
    

def Rotate(pointsToRotate, point2, theta):
    """
    adapted from: https://stackoverflow.com/questions/17763655/rotation-of-a-point-in-3d-about-an-arbitrary-axis-using-python
    needs to be origin
    rotates given:
    pointToRotate: the atoms to rotate around the axis
    point2: the coordinates to define one of the axes (eg. the metal)
    theta: the angle to rotate through
    """
    diff = -point2
    # make it unit norm
    u = diff / np.linalg.norm(diff)
    r = R(theta, u)
    rotated = []
    orig_shape = pointsToRotate.shape
    for point in pointsToRotate:
        for i in range(3):
            rotated.append(sum([r[j][i] * point[j] for j in range(3)]))
    
    return list(np.array(rotated).reshape(orig_shape))

# %%
pyr_atoms = [7, 6, 6, 6, 6, 6, 1, 1, 1, 1, 1]
pyr_pos = np.array([[0.6816, 1.1960, 0.0000],
           [1.3603, 0.0256, 0.0000],
           [0.6971, -1.2020, 0.0000],
           [-0.6944, -1.2184, 0.0000],
           [ -1.3895, -0.0129, 0.0000],
           [-0.6712, 1.1834, 0.0000],
           [2.4530, 0.1083, 0.0000],
           [ 1.2665, -2.1365, 0.0000],
           [-1.2365, -2.1696, 0.0000],
           [-2.4837, 0.0011, 0.0000],
           [-1.1569, 2.1657, 0.0000]
          ])
pyr_pos[:,0] = pyr_pos[:,0]-0.6816
pyr_pos[:,1] = pyr_pos[:,1]-1.1960
pyridine = Atoms(symbols=pyr_atoms,
                 positions=pyr_pos)
print(len(pyridine))
# Out:
# 11

# %%
string = """select ccdc_id, denticity, coordinating_elements, coordinating_indices, xyz from ligand_data 
            where (coordinating_elements like '%[8]%' or coordinating_elements like '%[7]%' 
            or coordinating_elements like '%[8, 7]%' or coordinating_elements like '%[7, 8]%') 
            and (denticity=3) and (original_metal=25 or original_metal=26 or original_metal=27 or original_metal=28)"""
# string = """select ccdc_id, denticity, coordinating_elements, coordinating_indices, xyz from ligand_data 
#             where (coordinating_elements like '%[7]%') 
#             and (denticity=3) and (original_metal=25 or original_metal=26 or original_metal=27 or original_metal=28)"""

count = 0 

def min_distance(coords, ligand_len):
    return np.mean(distance_matrix(coords[-ligand_len+1:], coords[:len(coords)-ligand_len]).flatten())

def add2tridentate(tri_ligand_xyz_str, connecting_indices, tmqm_id, ligand2add):
    """
    Args:
    tri_ligand_xyz_str: A string of the xyz of the separated tridentate ligand.
    connecting_indices: The indices of atoms in the ligand that connect to the metal.
    tmqm_id: The id stored in the ccdc
    ligand2add: Ase Atoms object, with the 0th index referring to the connecting point.
    """
    with open("tmp__.xyz", "w") as f:
        f.write(tri_ligand_xyz_str)
    ligand = io.read("tmp__.xyz")
    connecting_positions = np.zeros(shape=(3, 3))
    for idx, conn_idx in enumerate(connecting_indices):
        connecting_positions[idx] = ligand.positions[conn_idx]
    # define the vectors that make up the tridentate triangle
    vec1 = connecting_positions[0]-connecting_positions[1]
    vec2 = connecting_positions[1]-connecting_positions[2]
    vec3 = connecting_positions[0]-connecting_positions[2]
    # need mapping to determine which vertex of the triangle
    # is the point at which we have the highest angle.
    # The key is the index of the angles list, the value is the vertex index,
    # eg. vec1 and vec2 shre the index 1, so that is the intersection point.
    angle_idx2_vertex_idx = {0: 1, 1: 0, 2: 2}
    angles = [angle(-vec1, vec2), angle(vec1, vec3), angle(vec2, vec3)]
    sum_angles = sum(angles)
    opposite_atom = connecting_positions[angle_idx2_vertex_idx[np.argmax(angles)]]
    assert abs(sum_angles-3.141)<0.001
    angle_ratio = max(angles)/min(angles)
    if angle_ratio<1.4:
        # assume it is meriodonic ligand
        # TO DO: Handle meriodonic ligands.
        # I suppose since none of the atoms are opposite eachother,
        #  we could just take any atom.
        return

    tmqm_xyz = io.read("all_relevant_xyzs/{}.xyz".format(tmqm_id))
    metal_coord = tmqm_xyz.positions[np.argmax(tmqm_xyz.numbers)]
    
    # sanity check the position of atoms
    connecting_distances = set(distance_matrix(connecting_positions, connecting_positions).flatten())
    # remove the 0 value since atoms are obviously 0 Angstroms from themselves
    connecting_distances.remove(0)
    min_dist = min(connecting_distances)
    sum_distances = 0
    for dist in metal_coord-connecting_positions:
        sum_distances+=(np.linalg.norm(dist))
    avg_dist = sum_distances/3
    if avg_dist>min_dist:
        #  The connecting atoms are in some cases closer to eachother than the metal
        return 

    # add the tmqm ligand
    positions = np.append([metal_coord], ligand.positions, 0)
    # translate the original ligand xyz to the new position
    # define the direction at which we will add the atom
    metal2opposite = metal_coord-opposite_atom
    ligand_conn_pos = opposite_atom+2*metal2opposite
    ligand_positions = ligand2add.positions
    ligand_atoms = ligand2add.numbers
    translate_lig = ligand_positions[0]-ligand_conn_pos
    lig_pos = ligand_positions-translate_lig
    # add the new ligand
    pos_w_ligand = np.append(positions, lig_pos, 0)
    # make connecting point the origin
    pos_w_ligand = pos_w_ligand-lig_pos[0]
    angle_range = np.arange(0, 3.14, 0.2)
    # define other axes
    other_ax = np.array([pos_w_ligand[0][1], -pos_w_ligand[0][0], pos_w_ligand[0][2]])
    final_ax = np.array([pos_w_ligand[0][0], pos_w_ligand[0][2], -pos_w_ligand[0][1]])
    # first axis is defined as the position of the metal, since we set the 
    # connecting atom as the origin
    axes_def = (pos_w_ligand[0], other_ax, final_ax)
    min_dists = [0]
    print(lig_pos[0])
    for angles in combinations(angle_range, 3):
        pos2rotate = pos_w_ligand
        pos2rotate[-len(ligand2add)+1:] = Rotate(pos2rotate[-len(ligand2add)+1:], axes_def[0], angles[0])
        pos2rotate[-len(ligand2add)+1:] = Rotate(pos2rotate[-len(ligand2add)+1:], axes_def[1], angles[1])
        pos2rotate[-len(ligand2add)+1:] = Rotate(pos2rotate[-len(ligand2add)+1:], axes_def[2], angles[2])
        min_dist = min_distance(pos2rotate, len(ligand2add))
        if min_dist>max(min_dists):
            thing = Atoms([26]+list(ligand.numbers)+list(ligand2add.numbers), positions=pos2rotate)
            thing.write("save_as_opt.xyz")
            
for row in cur.execute(string):
    xyz_str = row[4]
    add2tridentate(row[4], json.loads(row[3]), row[0], pyridine)
    print('iterating over the function def for: {}'.format(row[0]))

for row in cur.execute(string):    
    xyz_str = row[4]
    print(row[0], row[1])
    with open("tmp__.xyz", "w") as f:
        f.write(xyz_str)
    ligand = io.read("tmp__.xyz")
    connecting_indices = json.loads(row[3])
    connecting_positions = np.zeros(shape=(row[1], 3))
    for idx, conn_idx in enumerate(connecting_indices):
        connecting_positions[idx] = ligand.positions[conn_idx]
    # define the vectors that make up the tridentate triangle
    vec1 = connecting_positions[0]-connecting_positions[1]
    vec2 = connecting_positions[1]-connecting_positions[2]
    vec3 = connecting_positions[0]-connecting_positions[2]
    # need mapping to determine which vertex of the triangle
    # is the point at which we have the highest angle.
    # The key is the index of the angles list, the value is the vertex index,
    # eg. vec1 and vec2 shre the index 1, so that is the intersection point.
    angle_idx2_vertex_idx = {0: 1, 1: 0, 2: 2}
    angles = [angle(-vec1, vec2), angle(vec1, vec3), angle(vec2, vec3)]
    sum_angles = sum(angles)
    opposite_atom = connecting_positions[angle_idx2_vertex_idx[np.argmax(angles)]]
    assert abs(sum_angles-3.141)<0.001
    angle_ratio = max(angles)/min(angles)
    if angle_ratio<1.4:
        # assume it is meriodonic ligand
        # TO DO: Handle meriodonic ligands.
        # I suppose since none of the atoms are opposite eachother,
        #  we could just take any atom.
        continue

    tmqm_xyz = io.read("all_relevant_xyzs/{}.xyz".format(row[0]))
    metal_coord = tmqm_xyz.positions[np.argmax(tmqm_xyz.numbers)]
    
    # sanity check the position of atoms
    connecting_distances = set(distance_matrix(connecting_positions, connecting_positions).flatten())
    # remove the 0 value since atoms are obviously 0 Angstroms from themselves
    connecting_distances.remove(0)
    min_dist = min(connecting_distances)
    sum_distances = 0
    for dist in metal_coord-connecting_positions:
        sum_distances+=(np.linalg.norm(dist))
    avg_dist = sum_distances/row[1]
    if avg_dist>min_dist:
        #  The connecting atoms are in some cases closer to eachother than the metal
        continue

    # add the tmqm ligand
    positions = np.append([metal_coord], ligand.positions, 0)
    # translate the original ligand xyz to the new position
    # define the direction at which we will add the atom
    metal2opposite = metal_coord-opposite_atom
    ligand_conn_pos = opposite_atom+2*metal2opposite
    translate_pyr = pyr_pos[0]-ligand_conn_pos
    pyridine_pos = pyr_pos-translate_pyr
    # add the new ligand
    pos_w_ligand = np.append(positions, pyridine_pos, 0)
    pos_w_ligand = pos_w_ligand-pyridine_pos[0]
    angle_range = np.arange(0, 3.14, 0.2)
    # define other axes
    other_ax = np.array([pos_w_ligand[0][1], -pos_w_ligand[0][0], pos_w_ligand[0][2]])
    final_ax = np.array([pos_w_ligand[0][0], pos_w_ligand[0][2], -pos_w_ligand[0][1]])
    # first axis is defined as the position of the metal, since we set the 
    # connecting atom as the origin
    axes_def = (pos_w_ligand[0], other_ax, final_ax)
    min_dists = [0]
    for angles in combinations(angle_range, 3):
        pos2rotate = pos_w_ligand
        pos2rotate[-len(pyridine)+1:] = Rotate(pos2rotate[-len(pyridine)+1:], axes_def[0], angles[0])
        pos2rotate[-len(pyridine)+1:] = Rotate(pos2rotate[-len(pyridine)+1:], axes_def[1], angles[1])
        pos2rotate[-len(pyridine)+1:] = Rotate(pos2rotate[-len(pyridine)+1:], axes_def[2], angles[2])
        min_dist = min_distance(pos2rotate, len(pyridine))
        if min_dist>max(min_dists):
            thing = Atoms([26]+list(ligand.numbers)+pyr_atoms, positions=pos2rotate)
            thing.write("save_as_opt.xyz")
        
    count+=1
    #print(planarness)
    #break
print(count)
plt.hist(mean_planarities)
# Out:
# [ 6.03940719 10.03304021  8.48141687]
# iterating over the function def for: ZAJGUP
# [14.62298244  8.60958063  6.38018096]
# iterating over the function def for: YAVKOY
# iterating over the function def for: DOPXIQ
# [-3.43370259e-05  1.02559911e+01 -1.80167408e+00]
# iterating over the function def for: XECVEJ
# iterating over the function def for: RANFIV
# [ 0.51817299  3.87169137 15.21122948]
# iterating over the function def for: WIJYAQ
# [4.48802286 4.57864686 9.02497705]
# iterating over the function def for: DOCWUO
# [14.43422657 12.33564302  7.50746194]
# iterating over the function def for: MEGZOP
# iterating over the function def for: GAJJAD
# iterating over the function def for: FEHFOO
# [-1.5763098   2.02121711  7.30969937]
# iterating over the function def for: HEBBEW
# iterating over the function def for: IGUWIR
# iterating over the function def for: LOCZUY
# [ 6.14798412  5.86655112 14.17130934]
# iterating over the function def for: LETKAX
# [ 5.72526103  0.42310937 -0.85237105]
# iterating over the function def for: IFEFUW
# iterating over the function def for: WUZVUJ
# [-2.1168518   4.81967639  7.78483244]
# iterating over the function def for: XAXYEA
# [0.14439442 3.82172069 3.16296022]
# iterating over the function def for: VIWSUR
# [4.05521175 0.56398235 3.08587866]
# iterating over the function def for: VEYTIF
# [ 2.73341606  4.54760133 11.73141768]
# iterating over the function def for: FIQNEB
# iterating over the function def for: HETRUU
# [ 4.78888854  3.91668641 16.72466956]
# iterating over the function def for: HUMZIA
# [9.80144991 5.64245875 3.35943497]
# iterating over the function def for: UNECOG
# [11.33550827  3.94658498 10.66198261]
# iterating over the function def for: YURSAF
# [6.01619819 6.05686655 5.62330583]
# iterating over the function def for: DANBOM
# [ 7.32926054  7.28877346 12.35138717]
# iterating over the function def for: GEMJOY
# [ 0.69600879 13.08021122  4.60718984]
# iterating over the function def for: MAKPUJ
# [2.90877034 3.37979933 2.29301626]
# iterating over the function def for: FENFEM
# [2.75632602 2.06602448 6.47100814]
# iterating over the function def for: NAJVAY
# [ 3.42665522 10.99458511  0.15690681]
# iterating over the function def for: UWUNUX
# [7.62077987 6.44992427 4.21882774]
# iterating over the function def for: SIYNUL
# [ 2.17157108 31.12544773  0.58658988]
# iterating over the function def for: OYINOA
# [4.14105298 3.87211612 5.67260455]
# iterating over the function def for: VEXFIP
# [2.03903984 4.40939376 2.31649239]
# iterating over the function def for: POJHON
# [4.32576305 5.17937874 3.55719764]
# iterating over the function def for: SICDOZ
# [3.57227599 3.45984168 4.84491181]
# iterating over the function def for: BIPRIE
# [7.83637394 6.51747402 9.7952125 ]
# iterating over the function def for: DAJGUT
# [5.34143369 2.08237659 0.90600212]
# iterating over the function def for: JISHAX
# iterating over the function def for: ZUGGEP
# iterating over the function def for: RAJBOV
# iterating over the function def for: WAVPAL
# [-6.89062644 15.94230341 12.40159246]
# iterating over the function def for: HILDEM
# [4.55405637 5.87878508 4.32265763]
# iterating over the function def for: ADORUG
# [-1.700764   10.03979972  0.72168139]
# iterating over the function def for: CIZGAW
# iterating over the function def for: DIHLIR
# [ 1.58977628 13.87735978  2.76893256]
# iterating over the function def for: OBIGAH
# [8.7198114  2.11710573 3.80478493]
# iterating over the function def for: IREHAO
# iterating over the function def for: TNBPMN
# [0.21313752 7.57168036 4.59591578]
# iterating over the function def for: PEKWUY
# [ 7.18612079  2.39494883 -0.01754135]
# iterating over the function def for: YOYMUV
# [3.93578186 5.92374392 2.94709191]
# iterating over the function def for: TUQQAY
# iterating over the function def for: UMACOB
# iterating over the function def for: ITEQIJ
# iterating over the function def for: HEJYAZ
# iterating over the function def for: FOPLIG
# [-0.84264375  8.78221329  4.19892859]
# iterating over the function def for: IYUBAF
# iterating over the function def for: FECCIC
# iterating over the function def for: GIQVOU
# [2.68455133 8.47309678 2.38772323]
# iterating over the function def for: QIGSAA
# [ 2.90099722 -0.88504979  2.03241278]
# iterating over the function def for: LOPTAM
# [ 6.11574098  7.08242458 31.61653825]
# iterating over the function def for: LANTOM
# iterating over the function def for: RATTUC
# [8.50558444 6.96821232 3.23542281]
# iterating over the function def for: NAYBEW
# [-3.92154732 11.06706423  4.12502311]
# iterating over the function def for: CARVEW
# iterating over the function def for: KEHNIV
# [5.66865369 3.93118124 6.75660197]
# iterating over the function def for: TULQOH
# [ 6.85667489  3.12074786 18.49663147]
# iterating over the function def for: OKUNOZ
# [6.12301094 6.07573352 3.00543058]
# iterating over the function def for: VIKXAO
# [9.56825101 9.32293695 2.02314183]
# iterating over the function def for: QUTJUM
# [ 1.12151673  7.18209057 26.60035569]
# iterating over the function def for: ETEFOA
# [ 5.51422269 14.18678888 10.66752749]
# iterating over the function def for: GIFFOR
# [1.67461675 1.84248011 0.09484334]
# iterating over the function def for: TISCIJ
# [4.30705993 8.99633797 1.15684271]
# iterating over the function def for: LIHGIT
# [-3.95619348 -7.8029183  -3.34608259]
# iterating over the function def for: MALVUS
# [-6.22098101  7.06594295  4.84698221]
# iterating over the function def for: NURSID
# iterating over the function def for: PULJAI
# [ 1.8927487   3.5756978  15.85562912]
# iterating over the function def for: XOQVIK
# [11.94242395  3.62055316 12.04929568]
# iterating over the function def for: XANRAG
# iterating over the function def for: EPIMIB
# [2.26503903 6.09359318 2.44946561]
# iterating over the function def for: VOHSIX
# [ 1.37969292  7.0371695  12.94246086]
# iterating over the function def for: UPELAD
# [ 1.99085869 -1.51887161 14.78194353]
# iterating over the function def for: SOZZEO
# iterating over the function def for: AMENCO
# [ 9.36578043  3.73071496 10.90165624]
# iterating over the function def for: TOYQUV
# [6.43322519 4.54894246 9.96492791]
# iterating over the function def for: DANQAN
# [8.10830008 6.22135871 3.99152134]
# iterating over the function def for: QOVLIY
# [8.57804901 2.84752372 3.1343176 ]
# iterating over the function def for: APAGOP
# [10.25769015 10.16979621  5.01142414]
# iterating over the function def for: PELCER
# [3.86031665 2.3762511  8.20208676]
# iterating over the function def for: LUXZOT
# [ 1.06743596  3.90195412 18.92096592]
# iterating over the function def for: QEPSEK
# [ 0.13861287 14.21460872 11.50146016]
# iterating over the function def for: HODVOO
# [ 0.10369912 14.77055848  3.10343697]
# iterating over the function def for: UDULEL
# [2.39666691 0.74738874 1.58373608]
# iterating over the function def for: AJIZAW
# [7.30202259 9.41080293 9.48548898]
# iterating over the function def for: YOHROD
# iterating over the function def for: ETGLNI
# [15.22442436 10.82901266 13.25874527]
# iterating over the function def for: ZAPQIT
# iterating over the function def for: EDIPIT
# iterating over the function def for: KEZRIR
# [-4.88839334  4.618839    3.89159983]
# iterating over the function def for: JEMCOU
# [4.23989152 0.06430652 1.86555601]
# iterating over the function def for: LILWIN
# [5.34332194 5.26277003 7.04963817]
# iterating over the function def for: AKOBAD
# [ 3.43936727 11.11588991 15.71751097]
# iterating over the function def for: EPAKAI
# [ 2.17540049  4.73239956 11.21290087]
# iterating over the function def for: HIPBOY
# [17.42195718  0.52595889  4.87346593]
# iterating over the function def for: WURKIE
# iterating over the function def for: LIXMOX
# iterating over the function def for: CADFAR
# [ 1.6240076   1.50267404 10.46917359]
# iterating over the function def for: LEZNIQ
# [2.99877041 4.40600916 8.01985912]
# iterating over the function def for: DANHOR
# [-0.84852749  1.23041335 13.66035832]
# iterating over the function def for: JAKHUY
# [ 7.26291903  3.54532204 10.7549677 ]
# iterating over the function def for: QAKREZ
# [ 3.56094683 14.14292279  9.10511782]
# iterating over the function def for: TIDBIS
# [9.92013031 0.62114489 1.43725226]
# iterating over the function def for: EXEMIF
# [2.744773   3.12666668 4.1047456 ]
# iterating over the function def for: QIGRIH
# [-5.65186075  4.93397256 16.93726842]
# iterating over the function def for: FEZJEB
# [2.52958056 8.02322591 9.9028853 ]
# iterating over the function def for: GIQNEA
# [12.72774189 -0.39006004 -1.95860021]
# iterating over the function def for: JACKOQ
# [-4.63755565  4.95276453 15.37084247]
# iterating over the function def for: AYEDAK
# [1.14089199 1.73029002 2.7958265 ]
# iterating over the function def for: VUCYUO
# iterating over the function def for: ANAJUW
# [ 7.75683013 10.86409426 11.19534896]
# iterating over the function def for: PAZBUQ
# iterating over the function def for: FEHFUU
# iterating over the function def for: UXOBEQ
# [0.93571785 6.98225759 1.73447757]
# iterating over the function def for: ICIRIX
# [3.04739097 4.7538956  0.87056565]
# iterating over the function def for: HEZMUW
# iterating over the function def for: ZOVPAB
# iterating over the function def for: ETIXIP
# iterating over the function def for: GISWIR
# [ 2.34097458 10.05857793  5.42284559]
# iterating over the function def for: QADPOA
# iterating over the function def for: CIGVAR
# [ 1.2584036  23.05737483  3.55102404]
# iterating over the function def for: RATXOB
# [ 0.74998108 -0.34244582  1.67027252]
# iterating over the function def for: QIVVIA
# [ 1.26997243 -0.4602718   4.15052391]
# iterating over the function def for: VAPVIT
# [2.82402577 1.95188226 2.66738774]
# iterating over the function def for: GUCXIL
# [0.77980299 6.72227192 4.89319139]
# iterating over the function def for: MIGBEK
# [ 4.21254346 12.30642663  1.51399612]
# iterating over the function def for: HAVQEC
# [1.57921552 2.51770102 2.04540994]
# iterating over the function def for: VUTGOI
# iterating over the function def for: OCAHAE
# [ 5.19949735  5.32907123 14.55826894]
# iterating over the function def for: OFAPIV
# [ 4.37784011  7.76673162 21.25824127]
# iterating over the function def for: EGOJOB
# iterating over the function def for: OYOHEQ
# [8.00194453 5.93395919 2.69975998]
# iterating over the function def for: JARMAQ
# [12.17250736  0.43013962  1.58470436]
# iterating over the function def for: YOYCUL
# [ 4.71768213  5.3652226  11.19270925]
# iterating over the function def for: MEWCIC
# iterating over the function def for: KODBUC
# [8.4333476  2.0498727  4.01371078]
# iterating over the function def for: TEHLIE
# [4.40616659 6.12167723 1.58640367]
# iterating over the function def for: FEJQOD
# [1.73836151 9.21720998 9.24205077]
# iterating over the function def for: AWOJAY
# [ 0.82000755  1.4195918  -1.93196696]
# iterating over the function def for: KAVVEJ
# iterating over the function def for: JEYHIH
# [2.07783867 0.80170989 2.71611413]
# iterating over the function def for: POJHUT
# iterating over the function def for: KETHUN
# [-6.22748142e-04  2.05741627e-01  2.63938684e+00]
# iterating over the function def for: KULMEJ
# [ 1.11007534 12.59181114  9.71684345]
# iterating over the function def for: OHUPUD
# iterating over the function def for: FASCAF
# [2.24169823 5.17164929 1.22667172]
# iterating over the function def for: BUWNUE
# [11.79265027  1.66934304  2.83185512]
# iterating over the function def for: MIHJAQ
# [ 0.67003371 -2.0434807  13.17659047]
# iterating over the function def for: ECIJIJ
# [1.6591037  6.0538018  1.39393652]
# iterating over the function def for: FOPRUY
# [ 1.61037983  1.97963498 10.98053079]
# iterating over the function def for: JIZZIC
# iterating over the function def for: RACNOB
# [5.23402943 8.27620145 2.33507384]
# iterating over the function def for: ULAMOK
# [7.06178087 3.24027707 5.24861507]
# iterating over the function def for: OHURUF
# [13.79433127  5.6621915  11.74700918]
# iterating over the function def for: CIRVEE
# iterating over the function def for: IPUHOQ
# [-0.41414115 -0.52596669 13.19654299]
# iterating over the function def for: XUHJUG
# [6.36501146 4.40591236 2.31911751]
# iterating over the function def for: AYITEI
# [12.73531548  3.84120347  0.18670628]
# iterating over the function def for: QETKIM
# iterating over the function def for: UQOXOP
# iterating over the function def for: XUMYAG
# [ 4.20198247 17.97182547  5.73904411]
# iterating over the function def for: QUGQUF
# [4.28931599 3.12310503 7.13268901]
# iterating over the function def for: YOBTIU
# [-1.4265258   2.1775672  10.64701288]
# iterating over the function def for: YITWII
# [ 1.56623058  4.84373653 12.50200815]
# iterating over the function def for: PESFUP
# [9.1414218  5.60003778 2.66343188]
# iterating over the function def for: BEMGEH
# [ 1.96553299  2.01083091 -2.02612426]
# iterating over the function def for: VEWQUK
# [4.69323089 3.40944107 8.24112956]
# iterating over the function def for: UXOJEY
# [-0.82250574  5.13267431  7.46330304]
# iterating over the function def for: DEBQAE
# [2.81734228 3.74097885 5.76323238]
# iterating over the function def for: DIXPEG
# [0.62982941 2.92017187 8.50785324]
# iterating over the function def for: MONTEQ
# [ 4.30202526  5.90293535 18.5862054 ]
# iterating over the function def for: HUZLEV
# [8.21612876 4.90107227 1.02596312]
# iterating over the function def for: NIBKIT
# [ 2.0492987  11.39299634 12.13326331]
# iterating over the function def for: NAXNOR
# [-0.84594942 -4.54169027  2.59582835]
# iterating over the function def for: MITYEU
# [4.51354261 1.11498244 2.39074569]
# iterating over the function def for: RAVSEN
# [-3.9963482  -0.33925351  6.4406944 ]
# iterating over the function def for: MONFOL
# [ 1.24297122  1.45751571 18.43728821]
# iterating over the function def for: QAXFUQ
# [11.01468892  5.14015156  0.35984209]
# iterating over the function def for: DEKHUY
# [-1.74367626  0.65216494 22.9965461 ]
# iterating over the function def for: CIZHIF
# [1.50079968 7.9929615  1.17186811]
# iterating over the function def for: OCUJOL
# [0.07441038 1.29804002 4.42899278]
# iterating over the function def for: WIWQUR
# iterating over the function def for: MIJJOH
# [6.22695794 4.68690851 6.93100138]
# iterating over the function def for: GAFYUJ
# [24.03682345  3.25866721 15.81199178]
# iterating over the function def for: FIZXUI
# [7.97991624 3.20587645 1.71665398]
# iterating over the function def for: YAKFEX
# [4.8882201  2.96454386 6.29277035]
# iterating over the function def for: IQUGIL
# [8.54326095 2.5178938  5.60516498]
# iterating over the function def for: FADCEU
# iterating over the function def for: INUTUH
# [5.4042222  1.63721919 8.82047587]
# iterating over the function def for: WOMRUN
# [5.48558457 2.60763284 3.14266267]
# iterating over the function def for: DOFTEY
# [ 1.29750214  1.51342075 10.52018306]
# iterating over the function def for: QELJOH
# [9.1940132  3.69609246 1.45717744]
# iterating over the function def for: VATWEV
# iterating over the function def for: QAFKOA
# iterating over the function def for: TUJGAH
# [3.09558921 9.16183904 4.10437003]
# iterating over the function def for: KOBBEJ
# iterating over the function def for: FAJZIB
# [-1.43026132  3.1790745   4.41060628]
# iterating over the function def for: XEFWAH
# [ 3.5827647  14.39734576  7.05147261]
# iterating over the function def for: BEZDIV
# [ 1.48084946  8.07069663 12.72073288]
# iterating over the function def for: RITJEK
# [3.28327464 0.89518101 6.41952866]
# iterating over the function def for: OZILEQ
# iterating over the function def for: QEBZEE
# [8.16636762 5.83662097 2.23124439]
# iterating over the function def for: SIXRAV
# [27.07739413 20.50881238  8.23039427]
# iterating over the function def for: BOTHAV
# iterating over the function def for: KEHNER
# [ 0.35255332 10.95078456  0.70144784]
# iterating over the function def for: KIRTUB
# iterating over the function def for: VUJRIC
# [10.24240474  5.88205709 -0.4634843 ]
# iterating over the function def for: VAPWAM
# [2.84090192 3.10048715 6.55323472]
# iterating over the function def for: PANCEO
# iterating over the function def for: UHOXAQ
# [15.62518673 -0.23453004 26.47849465]
# iterating over the function def for: QOYTEE
# iterating over the function def for: DAGJON
# iterating over the function def for: OVODUZ
# [-3.94478569  2.98381918  7.90580685]
# iterating over the function def for: AKOPEW
# [25.23155291  1.31173039  5.91996498]
# iterating over the function def for: DARMOA
# [10.21648983 11.34285437 11.57797788]
# iterating over the function def for: RIPHUW
# [1.59635595 2.07282345 6.73269375]
# iterating over the function def for: YOCFED
# iterating over the function def for: SAKVUY
# iterating over the function def for: PIZPEV
# [ 7.48350599 13.72435647  2.31036956]
# iterating over the function def for: REMZEP
# [ 2.02347389 14.08659817 -0.68988593]
# iterating over the function def for: XUBSIY
# [1.19097398 2.094283   0.97764809]
# iterating over the function def for: ISUGAF
# iterating over the function def for: KOCYUX
# [7.86438633 3.62495833 3.51117633]
# iterating over the function def for: BULYEM
# [7.36531275 6.15855519 4.83841873]
# iterating over the function def for: PAYTOZ
# iterating over the function def for: AQIREZ
# [ 2.94073749  0.40125301 15.08575495]
# iterating over the function def for: DUWGUZ
# [ 8.08338194 11.11556396  1.98091227]
# iterating over the function def for: SORJEP
# [-0.25218244 -1.09810676  3.18711126]
# iterating over the function def for: BEXFER
# [ 0.94453738  6.70984735 12.38672394]
# iterating over the function def for: LANTUS
# [ 3.05777755 -0.90384673  1.95182153]
# iterating over the function def for: QOHBOF
# [3.1762474  2.12635611 4.06298168]
# iterating over the function def for: GIVSEK
# [6.8770365  4.21538732 0.88999221]
# iterating over the function def for: SUGXOJ
# [5.78246425 1.24811558 1.18399458]
# iterating over the function def for: NOWVIE
# iterating over the function def for: QIFRAY
# [1.76858489 3.44600636 7.31414015]
# iterating over the function def for: QERZOC
# [ 0.91900339 11.26343897  9.83858082]
# iterating over the function def for: HEQBEN
# [12.04074262  2.54979482 19.09073506]
# iterating over the function def for: SUGXAV
# iterating over the function def for: KEZSAK
# [ 6.0239757  10.379943    4.11868231]
# iterating over the function def for: WECDOX
# [2.15536402 2.57967852 9.07333164]
# iterating over the function def for: HOQLUX
# iterating over the function def for: SILYIW
# [-0.27971734  2.73119235  4.69830123]
# iterating over the function def for: QOLYIB
# [-0.39774944  0.61230775  5.25242266]
# iterating over the function def for: DUWGOT
# iterating over the function def for: RACNUH
# iterating over the function def for: DPAZCO
# [3.09547885 6.71378412 5.20962891]
# iterating over the function def for: CURFUS
# [-0.89261421  4.80633605  4.96255132]
# iterating over the function def for: JAGSAO
# iterating over the function def for: PIBPIB
# iterating over the function def for: ESABAD
# iterating over the function def for: INUWEU
# iterating over the function def for: MAQSEF
# [7.38378473 1.37243706 3.19066848]
# iterating over the function def for: VAPTIR
# [0.81448704 5.04711864 7.50121599]
# iterating over the function def for: HIMNAV
# [ 0.82664327  6.38916406 15.36506967]
# iterating over the function def for: CENMUF
# [11.66056103 10.30484116  1.64270788]
# iterating over the function def for: IROVUH
# [ 4.10866142 15.64716557  6.25456219]
# iterating over the function def for: EQECIN
# [ 5.14630157 10.01119886  5.80832174]
# iterating over the function def for: NELCEP
# [6.35793965 4.98891835 4.04673268]
# iterating over the function def for: OBOJAT
# [7.73259161 5.09950792 0.2616479 ]
# iterating over the function def for: HAXZUD
# iterating over the function def for: NTMPNI
# [4.19341017 0.03725582 5.74998867]
# iterating over the function def for: OSODAD
# [-2.55710351  0.93119787  1.29297605]
# iterating over the function def for: LOPQEP
# [-0.92366275  2.61403905  4.03498726]
# iterating over the function def for: NUMLEM
# [ 6.15859229  4.6617442  -0.08501747]
# iterating over the function def for: EKEDEE
# iterating over the function def for: HAWNUQ
# [5.10698876 7.89554689 5.5851035 ]
# iterating over the function def for: HOQBAS
# [3.16510387 0.73512336 0.10971651]
# iterating over the function def for: IHOSUU
# [11.25686812  9.07196275  3.59282302]
# iterating over the function def for: HOBQAR
# [0.74666297 2.57504292 2.45488036]
# iterating over the function def for: REXZOL
# [ 2.44334717 11.43739844  8.04960132]
# iterating over the function def for: UHUSEW
# [14.8210484   3.29360936 15.23686916]
# iterating over the function def for: PODVEK
# [ 5.24048905 13.59575486  0.31046916]
# iterating over the function def for: WACWUV
# [6.37578151 8.43194378 7.5503517 ]
# iterating over the function def for: VEWREV
# [-1.94438221 -0.61018211  8.84197725]
# iterating over the function def for: QAMGAO
# iterating over the function def for: TODZIX
# iterating over the function def for: PIZGEM
# iterating over the function def for: VOFLEK
# iterating over the function def for: QANREE
# iterating over the function def for: TOFBAT
# [2.23486348 6.39352729 5.16620823]
# iterating over the function def for: XUCVEW
# iterating over the function def for: RACHOV
# iterating over the function def for: ZORJAU
# [2.06969804 3.16205782 1.29796678]
# iterating over the function def for: XAXYIE
# [4.02830495 3.59215104 5.62262467]
# iterating over the function def for: LEDQUH
# iterating over the function def for: ROJGAB
# [ 5.68695191 -2.83748408  3.08456975]
# iterating over the function def for: GAQFEJ
# [ 2.79115121  2.31920305 -1.30934887]
# iterating over the function def for: ESAQOF
# [7.76148695 3.48628216 2.54809271]
# iterating over the function def for: RAMDUG
# [1.84829097 2.27609046 7.27208436]
# iterating over the function def for: HEFGEG
# iterating over the function def for: IRAYIL
# [-8.15590726 -9.46935684 -7.10282732]
# iterating over the function def for: YATSIY
# [ 7.98143374 14.23142363  5.42060765]
# iterating over the function def for: YOYNIK
# iterating over the function def for: QIHMAY
# iterating over the function def for: BAGSEK
# [3.02583875 3.90517742 1.81474425]
# iterating over the function def for: SUSTOP
# [2.96083351 4.75535356 1.01367264]
# iterating over the function def for: TAPUFE
# [2.6829604  2.74444494 2.08686535]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c1e8850ddbc4> in <module>
#      98 for row in cur.execute(string):
#      99     xyz_str = row[4]
# --> 100     add2tridentate(row[4], json.loads(row[3]), row[0], pyridine)
#     101     print('iterating over the function def for: {}'.format(row[0]))
#     102
#
# <ipython-input-11-c1e8850ddbc4> in add2tridentate(tri_ligand_xyz_str, connecting_indices, tmqm_id, ligand2add)
#      94         if min_dist>max(min_dists):
#      95             thing = Atoms([26]+list(ligand.numbers)+list(ligand2add.numbers), positions=pos2rotate)
# ---> 96             thing.write("save_as_opt.xyz")
#      97
#      98 for row in cur.execute(string):
#
# ~/anaconda3/envs/cat-play/lib/python3.7/site-packages/ase/atoms.py in write(self, filename, format, **kwargs)
#    1900         """
#    1901         from ase.io import write
# -> 1902         write(filename, self, format, **kwargs)
#    1903
#    1904     def iterimages(self):
#
# ~/anaconda3/envs/cat-play/lib/python3.7/site-packages/ase/io/formats.py in write(filename, images, format, parallel, append, **kwargs)
#     403
#     404     _write(filename, fd, format, io, images, parallel=parallel, append=append,
# --> 405            **kwargs)
#     406
#     407
#
# ~/anaconda3/envs/cat-play/lib/python3.7/site-packages/ase/io/formats.py in _write(filename, fd, format, io, images, parallel, append, **kwargs)
#     436                 mode = mode.replace('w', 'a')
#     437             fd = open_with_compression(filename, mode)
# --> 438         io.write(fd, images, **kwargs)
#     439         if open_new:
#     440             fd.close()
#
# ~/anaconda3/envs/cat-play/lib/python3.7/site-packages/ase/io/extxyz.py in write_xyz(fileobj, images, comment, columns, write_info, write_results, plain, vec_cell, append, tolerant)
#     871         fileobj.write('%s\n' % comm)
#     872         for i in range(natoms):
# --> 873             fileobj.write(fmt % tuple(data[i]))
#     874
#     875
#
# KeyboardInterrupt:

# %%
from openbabel import openbabel


def run_ff(filename)
    obConversion = openbabel.OBConversion()
    obConversion.SetInFormat("xyz")

    OBMol = openbabel.OBMol()
    obConversion.ReadFile(OBMol, "save_as_opt_axial.xyz")

    OBMol_thing = OBMol

    metals = list(range(21, 31))+list(range(39, 49))+list(range(72, 81))

    constr = openbabel.OBFFConstraints()
    # openbabel indexing starts at 1 ### !!!
    # convert metals to carbons for FF
    indmtls = []
    mtlsnums = []
    for iiat, atom in enumerate(openbabel.OBMolAtomIter(OBMol_thing)):
        if atom.GetAtomicNum() in metals:
            indmtls.append(iiat)
            mtlsnums.append(atom.GetAtomicNum())
            atom.SetAtomicNum(6)
    for cat in range(0, len(pos_w_ligand)-len(pyridine)):
        constr.AddAtomConstraint(cat+1)  # indexing babel
    # set up forcefield
    forcefield = openbabel.OBForceField.FindForceField("MMFF94")
    forcefield.Setup(OBMol_thing, constr)
    # force field optimize structure
    forcefield.ConjugateGradients(2500)
    forcefield.GetCoordinates(OBMol_thing)
    # reset atomic number to metal
    for i, iiat in enumerate(indmtls):
        OBMol_thing.GetAtomById(iiat).SetAtomicNum(mtlsnums[i])
    obConversion.WriteFile(OBMol_thing, 'ff.xyz')

# %%
obConversion.WriteFile(OBMol_thing, 'ff.xyz')
# Out:
# True

# %%
from openbabel import openbabel

obConversion = openbabel.OBConversion()
obConversion.SetInFormat("xyz")

OBMol = openbabel.OBMol()
obConversion.ReadFile(OBMol, "save_as_opt_axial.xyz")

OBMol_thing = OBMol

metals = list(range(21, 31))+list(range(39, 49))+list(range(72, 81))

constr = openbabel.OBFFConstraints()
# openbabel indexing starts at 1 ### !!!
# convert metals to carbons for FF
indmtls = []
mtlsnums = []
for iiat, atom in enumerate(openbabel.OBMolAtomIter(OBMol_thing)):
    if atom.GetAtomicNum() in metals:
        indmtls.append(iiat)
        mtlsnums.append(atom.GetAtomicNum())
        atom.SetAtomicNum(6)
for cat in range(0, 4):
    constr.AddAtomConstraint(cat+1)  # indexing babel
# set up forcefield
forcefield = openbabel.OBForceField.FindForceField("MMFF94")
forcefield.Setup(OBMol_thing, constr)
# force field optimize structure
forcefield.ConjugateGradients(2500)
forcefield.GetCoordinates(OBMol_thing)
# reset atomic number to metal
for i, iiat in enumerate(indmtls):
    OBMol_thing.GetAtomById(iiat).SetAtomicNum(mtlsnums[i])
obConversion.WriteFile(OBMol_thing, 'ff.xyz')
# Out:
# True
